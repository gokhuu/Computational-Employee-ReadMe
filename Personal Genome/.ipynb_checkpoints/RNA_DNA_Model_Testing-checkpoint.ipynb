# %% [markdown]
# # RNA and DNA Model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
rna = pd.read_csv('Organoid Files/all_autism_fpkm_iqr_1.5_outliers_multi_class.csv', header=0,index_col=0)
dna = pd.read_csv('DNA_csv/dna_table_edit_t_mutli_replicates.csv', header=0,index_col=0)
display(rna.head())
display(dna.head())
# Out:
#            Autism  CDK5RAP1    TMEM246       PKD1     EDEM1      LSM11  \
# PGP1-1          0  5.561823   9.167399   4.762467  4.259699   3.333153
# PGP1-2          0  2.050032   6.121957   3.086031  3.888580   3.064389
# PGP1-3          0  2.481599  14.205795   8.663784  2.988719  13.747564
# GM23716-1       0  4.396121  15.263531   8.198981  3.433083  13.873706
# GM23716-2       0  3.721746  14.125613  10.278191  3.331196  13.211928
#
#             COL26A1      CPSF6      DCTN5      TIMM9  ...    NHLRC3  \
# PGP1-1     5.245319  15.288924  10.670947  12.501312  ...  3.577807
# PGP1-2     4.530108  14.225061  11.109630  14.227982  ...  2.951153
# PGP1-3     6.189141  18.021990  15.850792   9.134396  ...  3.211442
# GM23716-1  5.018456  17.714552  15.832140   8.492397  ...  3.052629
# GM23716-2  5.620373  15.806883  15.434513   8.410669  ...  2.743381
#
#              CCDC130     PIK3C3    PRKAB2    EIF2B3  C15orf61       IPP  \
# ...

# %%
#label encoding
from sklearn.preprocessing import LabelEncoder
cat_features = [i for i in dna.columns]
encoder = LabelEncoder()
dna_encoded = dna[cat_features].apply(encoder.fit_transform)
dna_encoded
# Out:
#            chr1@792480  chr1@880238  chr1@887560  chr1@892745  chr1@916549  \
# 14765x2-1            1            1            1            1            0
# 14765x2-2            1            1            1            1            0
# 14765x2-3            1            1            1            1            0
# 14763x7-1            1            1            1            1            0
# 14763x7-2            1            1            1            1            0
# ...                ...          ...          ...          ...          ...
# GM25256-2            1            1            1            1            0
# GM25256-3            1            1            1            1            0
# PGP1-1               1            1            1            1            1
# PGP1-2               1            1            1            1            1
# PGP1-3               1            1            1            1            1
#
#            chr1@1158631  chr1@1246004  chr1@1268847  chr1@1276973  \
# ...

# %%
comb = rna.merge(dna_encoded, how='outer', left_index=True, right_index=True)
comb
# Out:
#            Autism  CDK5RAP1    TMEM246      PKD1     EDEM1      LSM11  \
# 1001-1        1.0  4.102123   5.449758  2.754897  4.421296   2.095513
# 1001-2        1.0  4.694169   5.454356  3.805587  4.818231   2.024392
# 1001-3        1.0  2.812362   1.189077  3.886320  6.843510   2.036510
# 1401-1        1.0  4.674325   5.576149  6.349399  3.780281   4.246606
# 1401-2        1.0  7.434831   5.909210  6.793024  5.334093   4.241920
# ...           ...       ...        ...       ...       ...        ...
# GM25256-3     0.0  2.650833   6.657273  7.137243  4.336089   3.736166
# GM25256-3     0.0  2.650833   6.657273  7.137243  4.336089   3.736166
# PGP1-1        0.0  5.561823   9.167399  4.762467  4.259699   3.333153
# PGP1-2        0.0  2.050032   6.121957  3.086031  3.888580   3.064389
# PGP1-3        0.0  2.481599  14.205795  8.663784  2.988719  13.747564
#
#             COL26A1      CPSF6      DCTN5      TIMM9  ...  chrX@149013727  \
# ...

# %%
cat_features.append('Autism')
for i in cat_features:
    comb[i] = pd.Categorical(comb[i])

y = comb.Autism
x = comb.iloc[:,1:]
x.shape
# Out:
# (75, 16776)
