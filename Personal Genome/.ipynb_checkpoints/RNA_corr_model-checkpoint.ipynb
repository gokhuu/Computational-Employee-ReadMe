# %% [markdown]
# # RNA Model trimmed data

# %%
#import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('fpkm_corr.csv', header=0,index_col=0)
df.head()
# Out:
#            Autism      HAUS4     RNF181       KXD1   C1orf86      IRAK1  \
# PGP1-1        0.0  12.629804  76.525449  30.429274  7.280333  10.555950
# PGP1-2        0.0   7.479163  64.371712  25.723551  8.316094   9.193199
# PGP1-3        0.0   4.118585  35.200909  19.739899  6.307552   1.128194
# GM23716-1     0.0   3.836036  34.668537  19.047699  4.057933   1.172776
# GM23716-2     0.0   4.588342  31.756722  19.372522  6.031917   0.621480
#
#               VIM-AS1     PDIA5     ACOT2    PDLIM2  ...     KLHL42  C16orf52  \
# PGP1-1     125.905261  8.136986  1.948624  2.679615  ...   6.978103  3.578051
# PGP1-2     105.934341  8.197034  2.535708  2.340497  ...   5.732223  2.880756
# PGP1-3     104.386052  2.946072  1.319370  1.068997  ...  10.292776  6.064095
# GM23716-1   87.691828  2.940691  1.239815  0.532084  ...  10.138596  5.483229
# GM23716-2  121.517858  2.507901  1.562625  0.931017  ...   9.259207  4.834569
#
# ...

# %%
from sklearn.model_selection import train_test_split

y = df.Autism
x = df.iloc[:,1:]

x_train, x_test, y_train,y_test = train_test_split(x,y,test_size = .1, random_state=50)

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score
from random import *

rand_state_nn = []
nn_acc = []
for j in range(100):

    random_state = randint(0,1000)
    rand_state_nn.append(random_state)
    nn = MLPClassifier(solver='adam',alpha=0.0001,max_iter=500, random_state=random_state)
    nn.fit(x_train,y_train)
    nn_prediction= nn.predict(x_test)

    nn_accuracy = accuracy_score(y_test, nn_prediction)
    nn_acc.append(nn_accuracy)

    #print('Model Accuracy: {}'.format(nn_accuracy*100))
    plt.plot(nn.loss_curve_)
    
print(np.mean(nn_acc)*100)
# Out:
# 48.0

# %%
from sklearn.ensemble import RandomForestClassifier
rand_state_rf = []
rf_acc = []
for j in range(100):
    random_state = randint(0,1000)
    rand_state_rf.append(random_state)
    
    rf = RandomForestClassifier(n_estimators=500, criterion='entropy',
                                random_state=random_state)
    rf.fit(x_train, y_train)
    rf_prediction = rf.predict(x_test)
    rf_accuracy = accuracy_score(y_test, rf_prediction)
    rf_acc.append(rf_accuracy)
    #print('Model Accuracy: {}'.format(rf_accuracy*100))

print(np.mean(rf_acc)*100)
# Out:
# 55.75
