# %% [markdown]
# # Multi Class Single Label  with IQR boundries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#import data
df = pd.read_csv('Organoid Files/all_autism_fpkm_t_threshold_multi_class.csv', header=0, index_col=0)
df.head()
# Out:
#            Autism  CDK5RAP1    TMEM246       PKD1     EDEM1      LSM11  \
# PGP1-1          0  5.561823   9.167399   4.762467  4.259699   3.333153
# PGP1-2          0  2.050032   6.121957   3.086031  3.888580   3.064389
# PGP1-3          0  2.481599  14.205795   8.663784  2.988719  13.747564
# GM23716-1       0  4.396121  15.263531   8.198981  3.433083  13.873706
# GM23716-2       0  3.721746  14.125613  10.278191  3.331196  13.211928
#
#             COL26A1      CPSF6      DCTN5     MRPS33  ...      UBE2T  \
# PGP1-1     5.245319  15.288924  10.670947  15.418737  ...  36.320081
# PGP1-2     4.530108  14.225061  11.109630  21.596005  ...  19.707959
# PGP1-3     6.189141  18.021990  15.850792   9.871680  ...  15.002978
# GM23716-1  5.018456  17.714552  15.832140   4.594193  ...  13.609106
# GM23716-2  5.620373  15.806883  15.434513   7.544800  ...  13.346974
#
#                 PTK7    EIF2B3      CDK16  C15orf61       GSTP1       IPP  \
# ...

# %%
y = df.Autism
x = df.iloc[:,1:]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

rfc_ss = RandomForestClassifier(n_estimators=100)
rfc_mm = RandomForestClassifier(n_estimators=100)
dtc_ss = DecisionTreeClassifier()
dtc_mm = DecisionTreeClassifier()

# %%
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

ss = StandardScaler()
mm = MinMaxScaler()

k = 5

kf = KFold(n_splits=k, random_state=None)

rf_score = []
dt_score = []

for train_index, test_index in kf.split(x):
    x_train, x_test = x.iloc[train_index:], x.iloc[test_index:]
    y_train, y_test = y[train_index], y[test_index]
    
    #scale data
    ss_train_x = ss.fit_transform(x_train)
    ss_test_x = ss.fit_transform(x_test)
    
    mm_train_x = mm.fit_transofmr(x_train)
    mm_test_x = mm.fit_transform(x_test)
    
    #fit the model
    rfc_ss.fit(ss_train_x, y_train)
    rfc_mm.fit(mm_train_x, y_train)
    
    dtc_ss.fit(ss_train_x, y_train)
    dtc_mm.fit(mm_train_x, y_train)
    
    #make prediction
    pred_ss_rfc = rfc_ss.predict(ss_test_x)
    pred_mm_rfc = rfc_ss.predict(mm_test_x)
    
    pred_ss_dtc = dtc_ss.predict(ss_test_x)
    pred_mm_dtc = dtc_ss.predict(mm_test_x)
    
    #record score
    rfc_ss_acc=accuracy_score(y_test,pred_ss_rfc)
    
    rfc_mm_acc=accuracy_score(y_test,pred_mm_rfc)
    
    dtc_ss_acc=accuracy_score(y_test,pred_ss_dtc)
    dtc_mm_acc=accuracy_score(y_test,pred_mm_dtc)
