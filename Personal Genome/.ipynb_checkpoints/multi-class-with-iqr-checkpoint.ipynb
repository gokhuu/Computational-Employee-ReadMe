# %% [markdown]
# # Multi Class Single Label  with IQR boundries
# By Brandon Khuu
# Last update: 5/4/2021
#
# ### Goal
# Create a multi-class single label classification neural network with mRNA read data(FPKM).
# The classes being classfied are Control(patient is not Autistic), 15q duplication(patient is Autistic), and 16p11 deletion(patient is autisitc)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#import data
df = pd.read_csv('Organoid Files/all_autism_fpkm_iqr_1.5_outliers_multi_class.csv', header=0, index_col=0)
df.head()
# Out:
#            Autism  CDK5RAP1    TMEM246       PKD1     EDEM1      LSM11  \
# PGP1-1          0  5.561823   9.167399   4.762467  4.259699   3.333153
# PGP1-2          0  2.050032   6.121957   3.086031  3.888580   3.064389
# PGP1-3          0  2.481599  14.205795   8.663784  2.988719  13.747564
# GM23716-1       0  4.396121  15.263531   8.198981  3.433083  13.873706
# GM23716-2       0  3.721746  14.125613  10.278191  3.331196  13.211928
#
#             COL26A1      CPSF6      DCTN5      TIMM9  ...    NHLRC3  \
# PGP1-1     5.245319  15.288924  10.670947  12.501312  ...  3.577807
# PGP1-2     4.530108  14.225061  11.109630  14.227982  ...  2.951153
# PGP1-3     6.189141  18.021990  15.850792   9.134396  ...  3.211442
# GM23716-1  5.018456  17.714552  15.832140   8.492397  ...  3.052629
# GM23716-2  5.620373  15.806883  15.434513   8.410669  ...  2.743381
#
#              CCDC130     PIK3C3    PRKAB2    EIF2B3  C15orf61       IPP  \
# ...

# %%
y = df.Autism
x = df.iloc[:,1:]

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import MinMaxScaler

dtc = DecisionTreeClassifier(splitter="best",max_depth=5,random_state=2,max_leaf_nodes=5)

mm = MinMaxScaler()

k = 6

kf = KFold(n_splits=k, random_state=0, shuffle=True)

acc_score =[]

for train_index, test_index in kf.split(x):
    x_train, x_test = x.iloc[train_index,:], x.iloc[test_index,:]
    y_train, y_test = y[train_index], y[test_index]
    
    #scale data
    mm_train_x = mm.fit_transform(x_train)
    mm_test_x = mm.fit_transform(x_test)
    
    #fit the model
    dtc.fit(mm_train_x, y_train)
    
    #make prediction
    dtc_pred = dtc.predict(mm_test_x)
    
    #record score
    dtc_acc=accuracy_score(y_test,dtc_pred)
    acc_score.append(dtc_acc)
    
avg_score = sum(acc_score)/k

print('Accuracy of each fold: {}'.format(acc_score))
print('Average Accuracy of the model: {}'.format(avg_score))
# Out:
# Accuracy of each fold: [0.75, 0.9166666666666666, 0.8333333333333334, 0.5833333333333334, 0.6666666666666666, 0.7272727272727273]
# Average Accuracy of the model: 0.7462121212121212
